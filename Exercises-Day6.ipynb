# %% [markdown]
# # Level

# %%
tpl1 = ()

# %%
sisters = ('Payal', 'Dipali')
brothers = ('Pranay', "Aman", "Atharv", "Kunal", "Pranav")

# %%
mix = sisters + brothers
print(mix)
# Out:
# ('Payal', 'Dipali', 'Pranay', 'Aman', 'Atharv', 'Kunal', 'Pranav')

# %%
mix  = list(mix)
mix.append('Bhimrao')
mix.append('Pratibha')
mix = tuple(mix)

# %%
print(mix)
family_members = tuple(mix)
# Out:
# ('Payal', 'Dipali', 'Pranay', 'Aman', 'Atharv', 'Kunal', 'Pranav', 'Bhimrao', 'Bhimrao', 'Pratibha', 'Bhimrao', 'Pratibha')

# %% [markdown]
# # Level 2

# %%
siblings, parents = family_members[0:7], family_members[7:]

# %%
print(siblings)
print(parents)
# Out:
# ('Payal', 'Dipali', 'Pranay', 'Aman', 'Atharv', 'Kunal', 'Pranav')
# ('Bhimrao', 'Bhimrao', 'Pratibha', 'Bhimrao', 'Pratibha')

# %%
fruits = ('Banana', 'Apple', 'Orange', 'Mango', 'Lemon')
Vegetables = ('Potato', 'Onion', 'Capsicum', 'Ladyfinger', 'Calyflower')
animals = ('Lion', 'Tiger', "Dog", 'Cat', 'Elephent', "Elegator", "Snake")
food_stuff_tp = fruits + Vegetables + animals
print(food_stuff_tp)
# Out:
# ('Banana', 'Apple', 'Orange', 'Mango', 'Lemon', 'Potato', 'Onion', 'Capsicum', 'Ladyfinger', 'Calyflower', 'Lion', 'Tiger', 'Dog', 'Cat', 'Elephent', 'Elegator', 'Snake')

# %%
food_stuff_lt = list(food_stuff_tp)
print(food_stuff_lt)
# Out:
# ['Banana', 'Apple', 'Orange', 'Mango', 'Lemon', 'Potato', 'Onion', 'Capsicum', 'Ladyfinger', 'Calyflower', 'Lion', 'Tiger', 'Dog', 'Cat', 'Elephent', 'Elegator', 'Snake']

# %%
len(food_stuff_tp)
print(food_stuff_tp[8:9])
# Out:
# ('Ladyfinger',)

# %%
print(food_stuff_lt[:3])
print(food_stuff_lt[14:])
# Out:
# ['Banana', 'Apple', 'Orange']
# ['Elephent', 'Elegator', 'Snake']

# %%
del food_stuff_tp

# %%
nordic_countries = ('Denmark', 'Finland','Iceland', 'Norway', 'Sweden')

# %%
print('Estonia' in nordic_countries)
# Out:
# False

# %%
print('Iceland' in nordic_countries)
# Out:
# True
