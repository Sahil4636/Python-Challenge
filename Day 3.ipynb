# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Operators in Python
# # 1. Assignment Operators
# # Assignment operators are used to assign values to variables.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 5
x +=3
print(x)
x -=3
print(x)
x /=3
print(x)
x *=3
print(x)
x %=3
print(x)
x //=3
print(x)
x **=3
print(x)
x = 5
x &=3
print(x)
x |=3
print(x)
x ^=3
print(x)
x >>=3
print(x)
x <<=3
print(x)
print(x := 3)
# Out:
# 8
# 5
# 1.6666666666666667
# 5.0
# 2.0
# 0.0
# 0.0
# 1
# 3
# 0
# 0
# 0
# 3

# %% [markdown]
# # 2. Arithmatic operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Addition:", 1+2)
print("Subtraction:", 2-1)
print("Multiplication:", 2*3)
print("Division:", 4/2)
print("Modulus:", 5%2)
print("Exponential or Power :", 2**3)
print("Floor Division:", 7//2)
print("floor Division:", 7//3)
# Out:
# Addition: 3
# Subtraction: 1
# Multiplication: 6
# Division: 2.0
# Modulus: 1
# Exponential or Power : 8
# Floor Division: 3
# floor Division: 2

# %% [markdown]
# # 3.Comparison Operators
# # In programming we compare values, we use comparison operators to compare two values. We check if a value is greater or less or equal to other value.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(3 > 2)
print(3 >= 2)
print(3 < 2)
print(2 < 3 )
print(2 <= 3)
print(3 == 2)
print(3 != 2)
print(len("mango")== len("avagandu"))
print(len("mango") != len("avagandu"))
print(len("mango")< len("avagandu"))
print(len("milk")== len("meat"))
print(len("milk") == len('potato'))
print(len("tomato")== len("potato"))
print(len("python") > len("dragon"))
# Out:
# True
# True
# False
# True
# True
# False
# True
# False
# True
# True
# True
# False
# True
# False

# %% [markdown]
# # In addition to the above comparison operator Python uses:
#
# #is: Returns true if both variables are the same object(x is y)
# #is not: Returns true if both variables are not the same object(x is not y)
# #in: Returns True if the queried list contains a certain item(x in y)
# #not in: Returns True if the queried list doesn't have a certain item(x not in y)

# %%
print("1 is 1", 1 is 1)
print("1 is not 2", 1 is not 2)
print("A in Asabeneh", 'A' in 'Asabeneh')
print("B is not in Asabeneh", 'B' in 'Asabenegh')
print("coding" in "coding for all")
print("a in an:", 'a' in 'an')
print('4 is 2**2', 4 is 2**2)
# Out:
# 1 is 1 True
# 1 is not 2 True
# A in Asabeneh True
# B is not in Asabeneh False
# True
# a in an: True
# 4 is 2**2 True

# %% [markdown]
# # 4.Logical Operators
# Unlike other programming languages python uses keywords and, or and not for logical operators. Logical operators are used to combine conditional statements:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(3 > 2 and 4 > 3)
print(3 > 2 and 4 < 3)
print(3 < 2 and 4 < 3)
print("True and True", True and True)
print(3 > 2 or 4 > 3)
print(3 > 2 or 4 < 3)
print(3 < 2 or 4 < 3)
print('True or Flase:', True or False)
print(not 3 > 2)
print(not True)
print(not False)
print(not not True)
print(not not False)
# Out:
# True
# False
# False
# True and True True
# True
# True
# False
# True or Flase: True
# False
# False
# True
# True
# False
