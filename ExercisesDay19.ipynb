# %% [markdown]
# # Level 1

# %%
def count_lines_words(filename):
    with open(filename, 'r') as file:
        text = file.read()
    
    words = len(text.split())
    lines = len(text.splitlines())

    return words, lines 

words, lines = count_lines_words('data/obama_speech.txt ')

print("Words:", words)
print("Lines:",  lines)

words, lines = count_lines_words('data/michelle_obama_speech.txt')

print("Words:", words)
print("Lines:",  lines)

words, lines = count_lines_words('data/donald_speech.txt')

print("Words:", words)
print("Lines:",  lines)

words, lines = count_lines_words('data/melina_trump_speech.txt')

print("Words:", words)
print("Lines:",  lines)
# Out:
# Words: 2400
# Lines: 66
# Words: 2204
# Lines: 83
# Words: 1259
# Lines: 48
# Words: 1375
# Lines: 33

# %%
import json

# %%
def most_spoken_language(filename, top):
    with open(filename, 'r', encoding = 'utf-8') as f:
        dct_json = json.load(f)
    
    dct = {}
    for  country in dct_json:
        for language in country['languages']:
            if language in dct:
                dct[language] +=1
            else:
                dct[language] = 1
    sorted_languages = sorted(dct.items(), key=lambda x: x[1], reverse = True)

    formatted = [(count, lang) for lang, count in sorted_languages]
    return formatted[:top]

most_spoken_language('data/countries_data.json',10)
# Out:
# [(91, 'English'),
#  (45, 'French'),
#  (25, 'Arabic'),
#  (24, 'Spanish'),
#  (9, 'Portuguese'),
#  (9, 'Russian'),
#  (8, 'Dutch'),
#  (7, 'German'),
#  (5, 'Chinese'),
#  (4, 'Serbian')]

# %%
def most_populated_countries(filename, top):
    with open(filename, 'r', encoding = 'utf-8') as f:
        countries = json.load(f)
    list = []
    for country in countries:
        new_dict = {k: country[k] for k in ['name', 'population']}
        list.append(new_dict)
    list = sorted(list, key=lambda x: x['population'], reverse =True )
    return list[:top]

most_populated_countries('data/countries_data.json', 10)
# Out:
# [{'name': 'China', 'population': 1377422166},
#  {'name': 'India', 'population': 1295210000},
#  {'name': 'United States of America', 'population': 323947000},
#  {'name': 'Indonesia', 'population': 258705000},
#  {'name': 'Brazil', 'population': 206135893},
#  {'name': 'Pakistan', 'population': 194125062},
#  {'name': 'Nigeria', 'population': 186988000},
#  {'name': 'Bangladesh', 'population': 161006790},
#  {'name': 'Russian Federation', 'population': 146599183},
#  {'name': 'Japan', 'population': 126960000}]

# %% [markdown]
# # Level 2

# %%
import re

with open('data\email_exchanges.txt', 'r') as file:
    data = file.read()
emails = re.findall(r'[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}', data)
unique_emails = list(set(emails))

print(unique_emails)
# Out:
# ['200801041610.m04GA5KP007209@nakamura.uits.iupui.edu', '200801041608.m04G8d7w007184@nakamura.uits.iupui.edu', '200801041502.m04F21Jo007031@nakamura.uits.iupui.edu', '200801040947.m049lUxo006517@nakamura.uits.iupui.edu', '200801042001.m04K1cO0007738@nakamura.uits.iupui.edu', '200801040932.m049W2i5006493@nakamura.uits.iupui.edu', 'antranig@caret.cam.ac.uk', 'gopal.ramasammycook@gmail.com', '200801041106.m04B6lK3006677@nakamura.uits.iupui.edu', '200801032205.m03M5Ea7005273@nakamura.uits.iupui.edu', '200801040905.m0495rWB006420@nakamura.uits.iupui.edu', '200801041515.m04FFv42007050@nakamura.uits.iupui.edu', 'hu2@iupui.edu', 'zqian@umich.edu', 'david.horwitz@uct.ac.za', '200801040023.m040NpCc005473@nakamura.uits.iupui.edu', '200801051412.m05ECIaH010327@nakamura.uits.iupui.edu', 'stephen.marquard@uct.ac.za', '200801042109.m04L92hb007923@nakamura.uits.iupui.edu', 'wagnermr@iupui.edu', 'rjlowe@iupui.edu', '200801041609.m04G9EuX007197@nakamura.uits.iupui.edu', 'postmaster@collab.sakaiproject
# ...

# %%
def find_most_common_words(text_or_file, a):
    try:
        with open(text_or_file, 'r', encoding='utf-8') as file:
            text = file.read()
    except:
        text = text_or_file

    words = re.findall(r'\b[a-zA-Z]+\b', text.lower())

    freq = {}

    for word in words:
        
        if word in freq:
            freq[word] += 1
        else:
            freq[word] = 1
    sorted_words = sorted(freq.items(), key=lambda x: x[1], reverse = True)
    formated = [(count, word) for word, count in sorted_words]

    return formated[:a]


print(find_most_common_words('data/obama_speech.txt', 10))
# Out:
# [(129, 'the'), (113, 'and'), (81, 'of'), (70, 'to'), (67, 'our'), (62, 'we'), (50, 'that'), (48, 'a'), (36, 'is'), (25, 'in')]

# %%
import contextlib
import contextlib
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    return text

def remove_support_words(text):
    stop_words = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up',
              'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]


    words = text.split()
    filtered = []

    for word in words:
        if word not in stop_words:
            filtered.append(word)

    return filtered
def chech_text_similarity(text1, text2):

    try:
        with open(text1, 'r') as f:
            text1 = f.read()
    except:
        pass
    try:
        with open(text2, 'r') as f:
            text2 = f.read()
    except:
        pass

    text1 = clean_text(text1)
    text2 = clean_text(text2)

    words1 = set(remove_support_words(text1))
    words2 = set(remove_support_words(text2))

    common = words1.intersection(words2)

    similarity = (len(common) / len(words1.union(words2))) * 100

    return similarity

print("Similarity= ",(chech_text_similarity('data/melina_trump_speech.txt', 'michelle_obama_speech.txt')))
# Out:
# Similarity=  0.0

# %%
find_most_common_words('data/romeo_and_juliet.txt', 10)
# Out:
# [(868, 'the'),
#  (800, 'and'),
#  (661, 'to'),
#  (658, 'i'),
#  (535, 'of'),
#  (530, 'a'),
#  (381, 'is'),
#  (378, 'in'),
#  (371, 'that'),
#  (367, 'you')]

# %%
import csv
def count_no_of_lines(filename, wrd):
    word = wrd
    count = 0
    with open(filename, 'r') as f:
        for line in f:
            if word.lower() in line.lower():
                count += 1
    return count

# %%
count_no_of_lines('data/hacker_news.csv', 'Python')
# Out:
# 179

# %%
count_no_of_lines('data/hacker_news.csv', 'JavaScript')
# Out:
# 184

# %%
def count_for_specific_word(filename, wrd):
    word = wrd
    count = 0
    with open(filename, "r") as file:
        reader = csv.reader(file)

        for row in reader:
            if "Java" in row:
                count += 1
    return count

# %%
count_for_specific_word('data/hacker_news.csv', 'java')
# Out:
# 0
