# %%
dog = dict()

# %%
dog["name"] = "Dogesh"
dog['color'] = 'Black'
dog['breed'] = 'Labra'
dog['legs'] = 4
dog["age"] = 6

# %%
dog
# Out:
# {'name': 'Dogesh', 'color': 'Black', 'breed': 'Labra', 'legs': 4, 'age': 6}

# %%
student = {
    'first_name' : "Sahil",
    "Last_name" : "Dhanvij",
    'gender': 'Male',
    'age': 21,
    'Marital_Status': "Unmarried",
    'Skills' : ['Python', "Escel", "Power BI", "Pandas", "Numpy", "Matplotlib"],
    'country': "India",
    'city': 'Nagpur',
    "address":{
        'street':'Space street',
        'zipcode': "441108"
    }
}

# %%
student
# Out:
# {'first_name': 'Sahil',
#  'Last_name': 'Dhanvij',
#  'gender': 'Male',
#  'age': 21,
#  'Marital_Status': 'Unmarried',
#  'Skills': ['Python', 'Escel', 'Power BI', 'Pandas', 'Numpy', 'Matplotlib'],
#  'country': 'India',
#  'city': 'Nagpur',
#  'address': {'street': 'Space street', 'zipcode': '441108'}}

# %%
len(student)
# Out:
# 9

# %%
print(student['Skills'])
# Out:
# ['Python', 'Escel', 'Power BI', 'Pandas', 'Numpy', 'Matplotlib']

# %%
print(type(student["Skills"]))
# Out:
# <class 'list'>

# %%
student['Skills'].append('SkikitLearn')

# %%
student['Skills'].append('PyTorch')

# %%
student
# Out:
# {'first_name': 'Sahil',
#  'Last_name': 'Dhanvij',
#  'gender': 'Male',
#  'age': 21,
#  'Marital_Status': 'Unmarried',
#  'Skills': ['Python',
#   'Escel',
#   'Power BI',
#   'Pandas',
#   'Numpy',
#   'Matplotlib',
#   'SkikitLearn',
#   'PyTorch'],
#  'country': 'India',
#  'city': 'Nagpur',
#  'address': {'street': 'Space street', 'zipcode': '441108'}}

# %%
print(student.keys())
# Out:
# dict_keys(['first_name', 'Last_name', 'gender', 'age', 'Marital_Status', 'Skills', 'country', 'city', 'address'])

# %%
print(student.values())
# Out:
# dict_values(['Sahil', 'Dhanvij', 'Male', 21, 'Unmarried', ['Python', 'Escel', 'Power BI', 'Pandas', 'Numpy', 'Matplotlib', 'SkikitLearn', 'PyTorch'], 'India', 'Nagpur', {'street': 'Space street', 'zipcode': '441108'}])

# %%
print(student.items())
# Out:
# dict_items([('first_name', 'Sahil'), ('Last_name', 'Dhanvij'), ('gender', 'Male'), ('age', 21), ('Marital_Status', 'Unmarried'), ('Skills', ['Python', 'Escel', 'Power BI', 'Pandas', 'Numpy', 'Matplotlib', 'SkikitLearn', 'PyTorch']), ('country', 'India'), ('city', 'Nagpur'), ('address', {'street': 'Space street', 'zipcode': '441108'})])

# %%
del student['country']

# %%
student
# Out:
# {'first_name': 'Sahil',
#  'Last_name': 'Dhanvij',
#  'gender': 'Male',
#  'age': 21,
#  'Marital_Status': 'Unmarried',
#  'Skills': ['Python',
#   'Escel',
#   'Power BI',
#   'Pandas',
#   'Numpy',
#   'Matplotlib',
#   'SkikitLearn',
#   'PyTorch'],
#  'city': 'Nagpur',
#  'address': {'street': 'Space street', 'zipcode': '441108'}}

# %%
del dog

# %%
dog
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 dog
#
# NameError: name 'dog' is not defined

# %%
student.pop('city')
# Out:
# 'Nagpur'

# %%
student.popitem()
# Out:
# ('address', {'street': 'Space street', 'zipcode': '441108'})

# %%
del student['gender']

# %%
student
# Out:
# {'first_name': 'Sahil',
#  'Last_name': 'Dhanvij',
#  'age': 21,
#  'Marital_Status': 'Unmarried',
#  'Skills': ['Python',
#   'Escel',
#   'Power BI',
#   'Pandas',
#   'Numpy',
#   'Matplotlib',
#   'SkikitLearn',
#   'PyTorch']}
