# %%
import math

# %%
age = 21
height = 5.3
complex_no = 1 + 3j

print(type(age))
print(type(height))
print(type(complex_no))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
base = int(input("Enter base :"))
height = float(input("Enter Height"))
area = base*height
print("The area of the triangle is", area)
# Out:
# The area of the triangle is 200.0

# %%
side_a = int(input("Enter side a:"))
side_b = int(input("Enter side b:"))
side_c = int(input("Enter side c:"))
perimeter = side_a+side_b+side_c
print("The Perimeter of the triangle is :", perimeter)
# Out:
# The Perimeter of the triangle is : 12

# %%
lenght = int(input("Enter the lenght:"))
width = int(input('Enter the width'))
area = lenght * width
print("The area of the rectangle is:",area)
# Out:
# The area of the rectangle is: 400

# %%
radius = float(input("Enter the radius:"))
area = 3.14*radius**2
circumference = 3.14*2*radius
print("The area of the circle is :",area)
print("The circuference of the circle is:", circumference)
# Out:
# The area of the circle is : 1256.0
# The circuference of the circle is: 125.60000000000001

# %%
x = int(input("Enter x:"))
y = 2*x - 2
print("The slope y is :", y)
# Out:
# The slope y is : 6

# %%
from math import sqrt
x1 , x2 = 4, 2 
y1, y2 = 6, 10

m = (y2-y1)/(x2-x1)
Edist = sqrt((x2-x1)**2 + (y2-y1)**2)

print("Slope is :", m)
print("Euclidian Distance is :", Edist)
# Out:
# Slope is : -2.0
# Euclidian Distance is : 4.47213595499958

# %%
print(y > m)
# Out:
# True

# %%
x = int(input("Enter x:"))
y = x**2 + 6*x + 9
print("y is :", y) # for -3 the value of y is 0
# Out:
# y is : 0

# %%
print(len("python") < len("dragon"))
# Out:
# False

# %%
print('on'in "python" and 'on' in 'dragon')
# Out:
# True

# %%
print("jargon" in "I hope this course is not full of jargon")
# Out:
# True

# %%
lenth = float(len("python"))
lenght = str(lenght)
print(type(lenght))
# Out:
# <class 'str'>

# %%
# how to check if the number is even
a = int(input("Enter the number :"))
print(a%2 == 0)
# Out:
# True

# %%
print(7//3 == 2.7)
# Out:
# False

# %%
print(type("10") == type(10))
# Out:
# False

# %%
hours = int(input("Enter hours :"))
Rate = int(input("Enter rate per hour"))
Earning = hours* Rate
print(" Your weekly earning is ", Earning)
# Out:
#  Your weekly earning is  1120

# %%
years= int(input("Enter the no of years you have lived :"))
print(f"You have lived for {60*60*24*365*years} seconds.")
# Out:
# You have lived for 3153600000 seconds.
