# %%
from datetime import datetime

# %%
now = datetime.now()
print(now.day)
print(now.month)
print(now.year)
print(now.hour)
print(now.minute)
print(now.timestamp())
# Out:
# 10
# 7
# 2026
# 23
# 23
# 1783706007.929954

# %%
print(now.strftime('%d-%m-%y %H:%M:%S'))
# Out:
# 10-07-26 23:23:27

# %%
from datetime import datetime
date_string = "5 December, 2019"
date_object = datetime.strptime(date_string, "%d %B, %Y")
print('date_object: ', date_object)
# Out:
# date_object:  2019-12-05 00:00:00

# %%
now  = datetime.now()

new_year = datetime(year=now.year + 1, month=1, day=1)
differecne = new_year - now
print("Time left for New Year:", differecne)
# Out:
# Time left for New Year: 174 days, 0:36:14.518144

# %%
start_date = datetime(1970, 1, 1)

diff = now - start_date
years = diff.days // 365
days = diff.days % 365
hours = diff.seconds // 3600
minutes = (diff.seconds % 3600) // 60
seconds = diff.seconds % 60
print(years, "years")
print(days, "days")
print(hours, "hours")
print(minutes, "minutes")
print(seconds, "seconds")
# Out:
# 56 years
# 204 days
# 23 hours
# 23 minutes
# 27 seconds
