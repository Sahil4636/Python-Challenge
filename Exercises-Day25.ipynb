# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/hacker_news.csv')
print(df.head())
# Out:
#          id                                              title  \
# 0  12224879                          Interactive Dynamic Video
# 1  11964716  Florida DJs May Face Felony for April Fools' W...
# 2  11919867       Technology ventures: From Idea to Enterprise
# 3  10301696  Note by Note: The Making of Steinway L1037 (2007)
# 4  10482257  Title II kills investment? Comcast and other I...
#
#                                                  url  num_points  \
# 0            http://www.interactivedynamicvideo.com/         386
# 1  http://www.thewire.com/entertainment/2013/04/f...           2
# 2  https://www.amazon.com/Technology-Ventures-Ent...           3
# 3  http://www.nytimes.com/2007/11/07/movies/07ste...           8
# 4  http://arstechnica.com/business/2015/10/comcas...          53
#
#    num_comments      author       created_at
# 0            52    ne0phyte   8/4/2016 11:52
# 1             1    vezycash  6/23/2016 22:20
# 2             1     hswarna   6/17/2016 0:01
# ...

# %%
df.tail()
# Out:
#              id                                              title  \
# 20093  12379592  How Purism Avoids Intels Active Management Tec...
# 20094  10339284          YC Application Translated and Broken Down
# 20095  10824382  Microkernels are slow and Elvis didn't do no d...
# 20096  10739875                      How Product Hunt really works
# 20097  11680777  RoboBrowser: Your friendly neighborhood web sc...
#
#                                                      url  num_points  \
# 20093  https://puri.sm/philosophy/how-purism-avoids-i...          10
# 20094  https://medium.com/@zreitano/the-yc-applicatio...           4
# 20095  http://blog.darknedgy.net/technology/2016/01/0...         169
# 20096  https://medium.com/@benjiwheeler/how-product-h...         695
# 20097              https://github.com/jmcarp/robobrowser         182
#
#        num_comments         author        created_at
# 20093             6  AdmiralAsshat    8/29/2016 2:22
# ...

# %%
title = df['title']
title
# Out:
# 0                                Interactive Dynamic Video
# 1        Florida DJs May Face Felony for April Fools' W...
# 2             Technology ventures: From Idea to Enterprise
# 3        Note by Note: The Making of Steinway L1037 (2007)
# 4        Title II kills investment? Comcast and other I...
#                                ...
# 20093    How Purism Avoids Intels Active Management Tec...
# 20094            YC Application Translated and Broken Down
# 20095    Microkernels are slow and Elvis didn't do no d...
# 20096                        How Product Hunt really works
# 20097    RoboBrowser: Your friendly neighborhood web sc...
# Name: title, Length: 20098, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20098 entries, 0 to 20097
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20098 non-null  int64
#  1   title         20098 non-null  object
#  2   url           17658 non-null  object
#  3   num_points    20098 non-null  int64
#  4   num_comments  20098 non-null  int64
#  5   author        20098 non-null  object
#  6   created_at    20098 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['id', 'title', 'url', 'num_points', 'num_comments', 'author',
#        'created_at'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (20098, 7)

# %%
filtered = df[df['title'].str.contains("Python")]
filtered
# Out:
#              id                                              title  \
# 102    10974870                From Python to Lua: Why We Switched
# 103    11244541          Ubuntu 16.04 LTS to Ship Without Python 2
# 144    10963528  Create a GUI Application Using Qt and Python i...
# 196    10716331  How I Solved GCHQ's Xmas Card with Python and ...
# 436    11895088  Unikernel Power Comes to Java, Node.js, Go, an...
# ...         ...                                                ...
# 19596  12061177  David Beazley  Python Concurrency from the Gro...
# 19851  10988468    Ask HN: How to automate Python apps deployment?
# 19861  11738470                          Moving Away from Python 2
# 19979  12524656                      Python vs. Julia Observations
# 19997  11735438  Show HN: Decorating: Animated pulsed for your ...
#
#                                                      url  num_points  \
# 102    https://www.distelli.com/blog/using-lua-for-ou...         243
# ...

# %%
filtered2 = df[df['title'].str.contains('JavaScript')]
filtered2
# Out:
#              id                                              title  \
# 267    12352636   Show HN: Hire JavaScript - Top JavaScript Talent
# 811    10741251  Ask HN: Are there any projects or compilers wh...
# 1045   11343334  If you write JavaScript tools or libraries, bu...
# 1092   10422726  Rollup.js: A next-generation JavaScript module...
# 1161   12461624               V8 JavaScript Engine: V8 Release 5.4
# ...         ...                                                ...
# 19348  11448301    Fotorama, a responsive JavaScript photo gallery
# 19547  12105148                 Another Kind of JavaScript Fatigue
# 19609  12203508  Lonely programmer detective uncovers the Mozil...
# 19884  12552131  Ask HN: Best Practices for CSS in a Modern Jav...
# 20068  12149183  Show HN: Parse recipe ingredients using JavaSc...
#
#                                                      url  num_points  \
# 267                              https://www.hirejs.com/           1
# ...
