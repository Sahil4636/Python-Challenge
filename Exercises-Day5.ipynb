# %%
lst = list()

# %%
lst = []

# %%
list1 = [1,2,"er", 6, 7]
print(list1)
# Out:
# [1, 2, 'er', 6, 7]

# %%
print(len(list1))
# Out:
# 5

# %%
print(list1[0])
print(list1[2])
print(list1[len(list1)-1])
# Out:
# 1
# er
# 7

# %%
mixed_data_types = ["Sahil", 21, 5.3, "Unmarried", "Butibori"]

# %%
it_companies = ["Facebook", "Microsoft", "Google", "Apple", "IBM", "Oracle", "Amazon"]

# %%
print(mixed_data_types)
print(it_companies)
# Out:
# ['Sahil', 21, 5.3, 'Unmarried', 'Butibori']
# ['Facebook', 'Microsoft', 'Google', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
print(len(it_companies))
# Out:
# 7

# %%
print(it_companies[0])
print(it_companies[4])
print(it_companies[-1])
# Out:
# Facebook
# IBM
# Amazon

# %%
it_companies[0] = 'Meta'
print(it_companies)
# Out:
# ['Meta', 'Microsoft', 'Google', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
it_companies.append('Nvidia')
print(it_companies)
# Out:
# ['Meta', 'Microsoft', 'Google', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Nvidia', 'Nvidia']

# %%
it_companies.pop()
# Out:
# 'Nvidia'

# %%
it_companies
# Out:
# ['Meta', 'Microsoft', 'Google', 'Apple', 'IBM', 'Oracle', 'Amazon', 'Nvidia']

# %%
it_companies.insert(4, 'Accenture')
print(it_companies)
# Out:
# ['Meta', 'Microsoft', 'Google', 'Apple', 'Accenture', 'Accenture', 'IBM', 'Oracle', 'Amazon', 'Nvidia']

# %%
it_companies.pop(4)
# Out:
# 'Accenture'

# %%
print(it_companies)
# Out:
# ['Meta', 'Microsoft', 'Google', 'Apple', 'Accenture', 'IBM', 'Oracle', 'Amazon', 'Nvidia']

# %%
it_companies[0] = it_companies[0].upper()
print(it_companies)
# Out:
# ['FACEBOOK', 'Microsoft', 'Google', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
print('Microsoft' in it_companies)
# Out:
# True

# %%
it_companies.sort()
print(it_companies)
# Out:
# ['Amazon', 'Apple', 'FACEBOOK', 'Google', 'IBM', 'Microsoft', 'Oracle']

# %%
it_companies.reverse
print(it_companies)
# Out:
# ['Oracle', 'Microsoft', 'IBM', 'Google', 'FACEBOOK', 'Apple', 'Amazon']

# %%
print(it_companies[:3])
# Out:
# ['Oracle', 'Microsoft', 'IBM']

# %%
print(it_companies[-3:])
# Out:
# ['FACEBOOK', 'Apple', 'Amazon']

# %%
print(it_companies[4:])
# Out:
# ['FACEBOOK', 'Apple', 'Amazon']

# %%
print(it_companies[2:5])
# Out:
# ['IBM', 'Google', 'FACEBOOK']

# %%
print(it_companies[3:4])
# Out:
# ['Google']

# %%
it_companies.pop(0)
# Out:
# 'Oracle'

# %%
del it_companies[4]

# %%
print(it_companies)
# Out:
# ['Microsoft', 'IBM', 'Google', 'FACEBOOK', 'Amazon']

# %%
del it_companies[2:3]

# %%
print(it_companies)
# Out:
# ['Microsoft', 'IBM', 'FACEBOOK', 'Amazon']

# %%
it_companies.clear()

# %%
it_companies
# Out:
# []

# %%
del it_companies

# %%
print(it_companies)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 print(it_companies)
#
# NameError: name 'it_companies' is not defined

# %%
front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node','Express', 'MongoDB']

web_page = front_end + back_end
print(web_page)
# Out:
# ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Node', 'Express', 'MongoDB']

# %%
full_stack = web_page.copy()

# %%
full_stack.insert(0, "Python")
full_stack.insert(1, 'SQL')

# %%
print(full_stack)
# Out:
# ['Python', 'SQL', 'Python', 'HTML', 'CSS', 'JS', 'React', 'Redux', 'Node', 'Express', 'MongoDB']

# %%
full_stack.pop(2)
# Out:
# 'Python'

# %%
full_stack
# Out:
# ['Python',
#  'SQL',
#  'HTML',
#  'CSS',
#  'JS',
#  'React',
#  'Redux',
#  'Node',
#  'Express',
#  'MongoDB']
